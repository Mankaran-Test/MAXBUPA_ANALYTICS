# %% [markdown]
# ### This is a work around the Jupyter notebook

# %%
## this is a comment
## importing the necessary packages
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading the data files

# %%
df= pd.read_csv('terrorismData.csv')

# %%
df.head(10)
# Out:
#    Year  Month  Day             Country       State  \
# 0  1970      7    2  Dominican Republic         NaN
# 1  1970      0    0              Mexico     Federal
# 2  1970      1    0         Philippines      Tarlac
# 3  1970      1    0              Greece      Attica
# 4  1970      1    0               Japan     Fukouka
# 5  1970      1    1       United States    Illinois
# 6  1970      1    2             Uruguay  Montevideo
# 7  1970      1    2       United States  California
# 8  1970      1    2       United States   Wisconsin
# 9  1970      1    3       United States   Wisconsin
#
#                         Region           City   Latitude   Longitude  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# ...

# %%
df.shape
# Out:
# (181691, 17)

# %%
for i in range(len(df.columns)):
    print(df.columns[i],end="/ ")
# Out:
# Year/ Month/ Day/ Country/ State/ Region/ City/ Latitude/ Longitude/ AttackType/ Killed/ Wounded/ Target/ Summary/ Group/ Target_type/ Weapon_type/

# %% [markdown]
# #### accessing columns and rows in Dataframs
# 1. COLUMNS USING DF. OR DF['COLUMN NAME']
# 2. ROW USING INDEX
# 3. pd.series.index and values
# 4. adding a condition
# 5. iloc()

# %%
df.iloc[:1,:2]
# Out:
#    Year  Month
# 0  1970      7

# %% [markdown]
# ## FEW FUNCTIONS
# 1. DROP
# 2. value_counts()
# 3.mean,sum, groupby
# 3. orderby
# 4.group by
# 4. MAP()
# 4. .APPLY()
# 5.

# %%
df["Country"].value_counts().values

# df.drop(0)
# Out:
# array([24636, 14368, 12731, 11960,  8306,  6908,  6096,  5320,  5235,
#         4292,  4142,  3907,  3849,  3347,  3249,  3022,  2836,  2743,
#         2693,  2479,  2478,  2365,  2249,  2227,  2201,  2194,  2183,
#         2050,  2016,  1970,  1709,  1648,  1565,  1275,  1215,   967,
#          815,   775,   761,   735,   684,   683,   613,   566,   546,
#          541,   524,   499,   402,   394,   371,   363,   332,   323,
#          314,   307,   293,   283,   273,   259,   252,   225,   220,
#          217,   213,   207,   203,   196,   190,   188,   159,   159,
#          154,   154,   151,   140,   132,   132,   130,   127,   118,
#          118,   115,   114,   114,   113,   111,   109,   101,   101,
#           99,    96,    91,    90,    89,    83,    82,    80,    78,
#           76,    74,    67,    66,    62,    59,    57,    56,    52,
#           52,    50,    50,    49,    48,    46,    41,    39,    38,
# ...

# %% [markdown]
# # q1.Problem Statement :
# The Most Dangerous city in Jammu and Kashmir and the terrorist group which is most active in that city?
# Print count of number of attacks in that city as integer

# %%
df_terrorism=df
#condition
df_terrorism=df_terrorism[df_terrorism['State']=='Jammu and Kashmir']
city_list=df_terrorism['City'].value_counts()
city=city_list.index[0]
attack=city_list.values[0]
city_list
# attack
# df_terrorism=df_terrorism[df_terrorism['City']==city]
# group=df_terrorism['Group'].value_counts().index[1]
# print(city,attack,group)
# Out:
# Srinagar     657
# Sopore       102
# Unknown       86
# Anantnag      76
# Jammu         57
#             ...
# Rainawari      1
# Siala          1
# Bachay         1
# Manwal         1
# Yamrach        1
# Name: City, Length: 633, dtype: int64
